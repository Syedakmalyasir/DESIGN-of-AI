# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd '/content/gdrive/My Drive/datasets'
# Out:
# /content/gdrive/My Drive/datasets

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import numpy as np

# %%
import pandas as pd
data=pd.read_csv("Iris.csv")
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder,StandardScaler

# %%
le=LabelEncoder()
data["Species"]=le.fit_transform(data["Species"])
data["Species"].value_counts()
# Out:
# 0    50
# 1    50
# 2    50
# Name: Species, dtype: int64

# %%
import seaborn as sns
sns.boxplot(data["SepalLengthCm"])
# Out:
# <Axes: ylabel='SepalLengthCm'>

# %%
import seaborn as sns
sns.boxplot(data["SepalWidthCm"])
# Out:
# <Axes: ylabel='SepalWidthCm'>

# %%
out1=np.where(data["SepalWidthCm"]>4)
out1
# Out:
# (array([15, 32, 33]),)

# %%
m=data["SepalWidthCm"].mean(axis=0)

# %%
l=[]
for i in out1:
  l.append(data["SepalWidthCm"][i])

# %%
data["SepalWidthCm"]=data["SepalWidthCm"].replace(to_replace=l,value=m)

# %%
sns.boxplot(data["SepalWidthCm"])
# Out:
# <Axes: ylabel='SepalWidthCm'>

# %%
out2=np.where(data["SepalWidthCm"]<2.2)
out2
# Out:
# (array([60]),)

# %%
l=[]
for i in out2:
  l.append(data["SepalWidthCm"][i])

# %%
data["SepalWidthCm"]=data["SepalWidthCm"].replace(to_replace=l,value=m)

# %%
sns.boxplot(data["SepalWidthCm"])
# Out:
# <Axes: ylabel='SepalWidthCm'>

# %%
sns.boxplot([data['PetalLengthCm']])
# Out:
# <Axes: >

# %%
sns.boxplot(data["PetalWidthCm"])
# Out:
# <Axes: ylabel='PetalWidthCm'>

# %%
x0=data.drop(data.iloc[:,5:6],axis=1)
x0
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
# [150 rows x 5 columns]

# %%
x=x0.drop(data.iloc[:,0:1],axis=1)
x
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
y=data.drop(data.iloc[:,:-1],axis=1)

# %%
y
# Out:
#      Species
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ..       ...
# 145        2
# 146        2
# 147        2
# 148        2
# 149        2
#
# [150 rows x 1 columns]
